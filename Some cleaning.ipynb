# %%
df <- read.csv(file="data_020320.csv",sep=",",header=TRUE)

# %%
colnames(df)
dim(df)
# Out:
#  [1] "X"                            "X1st.Term.Funding"
#  [3] "X2nd.Term.Funding"            "X3rd.Term.Funding"
#  [5] "X4th.Term.Funding"            "Academic.Period.Matriculated"
#  [7] "Age.at.Matriculation"         "COLLEGE_DESC"
#  [9] "CURRENT_AGE"                  "DEGREE_DESC"
# [11] "GENDER_DESC"                  "Grad.Funding.Indicator"
# [13] "ID"                           "Citizenship"
# [15] "MAJOR"                        "MAJOR_DESC"
# [17] "Net.Cost.After.Any.Funding"   "PROGRAM_DESC"
# [19] "Prep.Level"                   "Total.Charges"
# [21] "Total.Funding.Amount"         "Y"
# [23] "PC1"                          "PC2"
# [25] "PC3"                          "Term.1.GPA"
# [27] "Term.2.GPA"                   "Term.3.GPA"
# [29] "Term.4.GPA"                   "Term.5.GPA"
# [31] "Term.6.GPA"                   "Term.7.GPA"
# [33] "Term.8.GPA"                   "Gap"
# [35] "Slope"                        "Valid.term"
# [37] "Average"                      "Academic.Period..Years."
# [1] 2470   38

# %%
colnames(df)[2] = '1st_Term_Funding'
colnames(df)[3] = '2nd_Term_Funding'
colnames(df)[4] = '3rd_Term_Funding'
colnames(df)[5] = '4th_Term_Funding'
colnames(df)[6] = 'Start_year'
colnames(df)[7] = 'Start_age'
colnames(df)[8] = 'College'
colnames(df)[9] = 'Age'
colnames(df)[10] = 'Degree'
colnames(df)[11] = 'Gender'
colnames(df)[12] = 'funding_indicator'
colnames(df)[15] = 'Major_id'
colnames(df)[16] = 'Major'
colnames(df)[17] = 'net_cost'
colnames(df)[18] = 'Program'
colnames(df)[34] = 'gap_indicator'
colnames(df)[35] = 'GPA_trend'
colnames(df)[37] = 'Average_GPA'
colnames(df)[38] = 'academic_period'
colnames(df)
dim(df)
# Out:
#  [1] "X"                    "1st_Term_Funding"     "2nd_Term_Funding"
#  [4] "3rd_Term_Funding"     "4th_Term_Funding"     "Start_year"
#  [7] "Start_age"            "College"              "Age"
# [10] "Degree"               "Gender"               "funding_indicator"
# [13] "ID"                   "Citizenship"          "Major_id"
# [16] "Major"                "net_cost"             "Program"
# [19] "Prep.Level"           "Total.Charges"        "Total.Funding.Amount"
# [22] "Y"                    "PC1"                  "PC2"
# [25] "PC3"                  "Term.1.GPA"           "Term.2.GPA"
# [28] "Term.3.GPA"           "Term.4.GPA"           "Term.5.GPA"
# [31] "Term.6.GPA"           "Term.7.GPA"           "Term.8.GPA"
# [34] "gap_indicator"        "GPA_trend"            "Valid.term"
# [37] "Average_GPA"          "academic_period"
# [1] 2470   38

# %%
lc = levels(df$Citizenship)
as.matrix(lc)
# Out:
#       [,1]
#  [1,] Afria
#  [2,] Africa
#  [3,] American Indian or Alaskan Native
#  [4,] Asia
#  [5,] Asian
#  [6,] Black or African American
#  [7,] China
#  [8,] Europe
#  [9,] Hawaiian or Other Pacific Islander
# [10,] Hispanic or Latino
# [11,] India
# [12,] North America
# [13,] South America
# [14,] Unknown
# [15,] White

# %%
df$Citizenship[which(df$Citizenship=='Afria')]=lc[2]
df$Citizenship = droplevels(df$Citizenship)
as.matrix(levels(df$Citizenship))
# Out:
#       [,1]
#  [1,] Africa
#  [2,] American Indian or Alaskan Native
#  [3,] Asia
#  [4,] Asian
#  [5,] Black or African American
#  [6,] China
#  [7,] Europe
#  [8,] Hawaiian or Other Pacific Islander
#  [9,] Hispanic or Latino
# [10,] India
# [11,] North America
# [12,] South America
# [13,] Unknown
# [14,] White

# %%
write.csv(df, file = "data_020320_cleaned")

# %%
df$Citizenship[df$Citizenship=='Asian']
# Out:
#   [1] <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA>
#  [16] <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA>
#  [31] <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA>
#  [46] <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA>
#  [61] <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA>
#  [76] <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA>
#  [91] <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA> <NA>
# 14 Levels: Africa American Indian or Alaskan Native Asia ... White
